# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from config.paths import RAW_DATA

# %%
import numpy as np
import pandas as pd

# --- Visualization ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Project paths ---
from config.paths import RAW_DATA, PROCESSED_DATA

# --- Display settings ---
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 100)
plt.style.use("seaborn-v0_8")

# %%
print(RAW_DATA)
print(PROJECT_ROOT)
# Out:
# /home/kingpin/kaggleprojects/Projects_VS_Code/Kaggle_Ames_housing/data/raw
# /home/kingpin/kaggleprojects/Projects_VS_Code/Kaggle_Ames_housing

# %%
train_df = pd.read_csv(RAW_DATA / "train.csv")
test_df = pd.read_csv(RAW_DATA / "test.csv")

# %%
train_df.shape
# Out:
# (1460, 81)
